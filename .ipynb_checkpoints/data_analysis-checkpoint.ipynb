# %%
import pandas as pd 
import numpy as np 
#import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
maindf = pd.read_csv('datasets-13720-18513-insurance.csv.csv')
maindf.shape
# Out:
# (1338, 7)

# %%
maindf
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### Data Analysis

# %% [markdown]
# Age Group

# %%
maindf['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
maindf.reset_index().groupby('age')['index'].count().plot(kind='bar',figsize=(10,10))
pd.DataFrame(maindf.reset_index().groupby('age')['index'].count().reset_index()).plot(kind='scatter',x='age',y='index')
# Out:
# <AxesSubplot:xlabel='age', ylabel='index'>

# %% [markdown]
# Age with Charges visual

# %%
maindf[['age','charges']].plot(kind='scatter',x='age',y='charges',c='DarkBlue',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
#boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
maindf.boxplot(column=['age', 'bmi', 'children'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data Analysis on Gender

# %%
maindf['sex'].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
#maindf['sex']
maindf['sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Relationship with Charges

# %%
temp  = maindf[['sex','charges']]
temp['charges_male']= temp[temp['sex']=='male']['charges']
temp['charges_female']  = temp[temp['sex']!='male']['charges']
temp = temp.sort_values('charges',ascending=False)
temp[['sex', 'charges_male', 'charges_female']].set_index('sex').plot(figsize=(7,7),subplots=True)
# Out:
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\user\AppData\Roaming\Python\Python36\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# array([<AxesSubplot:xlabel='sex'>, <AxesSubplot:xlabel='sex'>],
#       dtype=object)

# %%
temp['charges_male'].describe()
# Out:
# count      676.000000
# mean     13956.751178
# std      12971.025915
# min       1121.873900
# 25%       4619.134000
# 50%       9369.615750
# 75%      18989.590250
# max      62592.873090
# Name: charges_male, dtype: float64

# %%
temp['charges_female'].describe()
# Out:
# count      662.000000
# mean     12569.578844
# std      11128.703801
# min       1607.510100
# 25%       4885.158700
# 50%       9412.962500
# 75%      14454.691825
# max      63770.428010
# Name: charges_female, dtype: float64

# %%
temp=maindf.copy()
temp.loc[temp['sex']=='male','sex']=str(1)
temp.loc[temp['sex']!='1','sex']=str(2)

temp['sex']= temp['sex'].astype(int)
#temp['sex'].unique()
temp[['sex','charges']].plot(kind='scatter',x='sex',y='charges')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %% [markdown]
# Data Analaysis on BMI

# %%
maindf['bmi'].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
maindf[['bmi','charges']].plot(kind='scatter',x='bmi',y='charges')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# Data Analysis with children

# %%
maindf.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
maindf['children'].describe()
# Out:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
maindf['children'].value_counts().plot(kind='bar',rot=0)
# Out:
# <AxesSubplot:>

# %%
maindf[['children','charges']].plot(kind='scatter',x='children',y='charges')
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %% [markdown]
# Data Analysis on Smoker

# %%
maindf['smoker'].describe()
# Out:
# count     1338
# unique       2
# top         no
# freq      1064
# Name: smoker, dtype: object

# %%
maindf['smoker'][maindf['smoker']=='no'] = str(0)
maindf['smoker'][maindf['smoker']!='0'] = str(1)
maindf['smoker'] = maindf['smoker'].astype(int)
# Out:
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
maindf[['smoker','charges']].plot(kind='scatter',x='smoker',y='charges')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# Data Analysis on Region

# %%
maindf['region'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
temp = maindf[['region','charges']].copy()
temp['temp'] = np.nan
q=-1
for region in maindf['region'].unique():
    q+=1
    temp.loc[temp['region']==region,'temp'] = str(q)
    print(region,' = ',q)
    
temp['region'] = np.nan
temp['region']= temp['temp']
temp['region'] = temp['region'].astype(int)
del temp['temp']
temp[['region','charges']].plot(kind='scatter',x='region',y='charges')
# Out:
# southwest  =  0
# southeast  =  1
# northwest  =  2
# northeast  =  3
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %% [markdown]
# Correlation of each variable with charges

# %%
# maindf.corr()['charges'].sort_values(ascending=False)[1:]*100

# %%
maindf = pd.read_csv('datasets-13720-18513-insurance.csv.csv')

# %%
temp = maindf.copy()
temp.loc[temp['sex']=='male','sex']=str(1)
temp.loc[temp['sex']!='1','sex']=str(2)

temp['sex']= temp['sex'].astype(int)

temp['smoker'][temp['smoker']=='no'] = str(0)
temp['smoker'][temp['smoker']!='0'] = str(1)
temp['smoker'] = temp['smoker'].astype(int)



temp['temp'] = np.nan
q=-1
for region in maindf['region'].unique():
    q+=1
    temp.loc[temp['region']==region,'temp'] = str(q)
    #print(region,' = ',q)
    
temp['region'] = np.nan
temp['region']= temp['temp']
temp['region'] = temp['region'].astype(int)
del temp['temp']
maindf = temp.copy()
# Out:
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# e:\software\anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
maindf.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
maindf.corr()['charges'].sort_values(ascending=False)[1:]
# Out:
# smoker      0.787251
# age         0.299008
# bmi         0.198341
# children    0.067998
# region      0.006208
# sex        -0.057292
# Name: charges, dtype: float64

# %% [markdown]
# · Finding correlations between different categories, e.g. bmi vs charges, smokers vs charges, children vs charges
#     ans: It seems smoker is high correlated with charges and same pattern can be seen in visual of
#          smoker vs charges
#
# · What categories contributed more to the health cost, if so & why?
#     ans: categories columns : smoker,children,region
#          Yes smoker is contrbuting most to the health cost  , and rightly so smokers are more vulnerable to lungs cancer,
#              and other type of cancer , so they are do spend more on them.
#
# · What are the effects of medical/health cost between male & female, cigarettes usage, BMI effects?
#     ans: effect of health cost  on sex:
#                 Gender is not contributing at all to charges, means gender has no effect ,
#                 on charges . Either you are male and female charges are unrelated to this.
#          effect of cigrattes (smoker) on health cost:
#                  As obvious, smokers are more vulnerable to health issues so they do have more charges than
#                  non-smoker
#          effect of BMI on health cost :
#                  As shown in above visual 'bmi vs charges' , there is a mix of response on charges , low bmi
#                  also have high charges and high bmi do also have high charges, and correlation also close 0
#                  so we can say that BMI has no effect on health cost.
